# %%
import pandas as pd

# Load dataset
dataset = r"D:\IIIT dharwad\lr\Salary_dataset.csv"
df = pd.read_csv(dataset,usecols=['YearsExperience', 'Salary'])

# Assign proper column names (if needed)
df.columns = ['YearsExperience', 'Salary']

# Show first few rows
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['YearsExperience'], df['Salary'], color='blue', label='Data points')
plt.xlabel("height")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)  # correlation matrix
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
import numpy as np
import pandas as pd

dataset = r"D:\IIIT dharwad\lr\Salary_dataset.csv"
df = pd.read_csv(dataset,usecols=['YearsExperience', 'Salary'])

np.max(np.abs(df['Salary']))
df['scaled_data'] = df['Salary'] / np.max(np.abs(df['Salary']))
print(scaled_data.head())
X=df[['YearsExperience']]
y=df['scaled_data']

print(X.head())
print(y.head())
# Out:
# 0    0.321459
# 1    0.377525
# 2    0.308288
# 3    0.355628
# 4    0.325936
# Name: Salary, dtype: float64
#    YearsExperience
# 0              1.2
# 1              1.4
# 2              1.6
# 3              2.1
# 4              2.3
# 0    0.321459
# 1    0.377525
# 2    0.308288
# 3    0.355628
# 4    0.325936
# Name: scaled_data, dtype: float64

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, train_size=0.80, random_state=42)


print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (24, 1) (24,)
# Testing set shape: (6, 1) (6,)

# %%
len(X_train)
# y_train
X_test
# Out:
#     YearsExperience
# 27              9.7
# 15              5.0
# 23              8.3
# 17              5.4
# 8               3.3
# 9               3.8

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results.head())
# Out:
#       Actual  Predicted
# 27  0.920289   0.946068
# 15  0.555093   0.584183
# 23  0.929906   0.838273
# 17  0.678876   0.614981
# 8   0.526554   0.453288

# %%
plt.plot(y_test.values, label="Actual", marker='o')
plt.plot(y_pred, label="Predicted", marker='o')
plt.xlabel("Sample Index")
plt.ylabel("Target Value")
plt.title("Actual vs Predicted (Line Plot)")
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("R² Score:", r2)
print("Mean Squared Error:", mse)
# Out:
# R² Score: 0.9024461774180497
# Mean Squared Error: 0.003326485755526519

# %%
model.score(X_test, y_test)
# Out:
# 0.9024461774180497
